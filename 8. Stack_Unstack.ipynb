# %% [markdown]
# # 12 Stack and Unstack

# %%
import pandas as pd

# %%
df=pd.read_excel("stocks.xlsx")
df
# Out:
#             Unnamed: 0     Price Unnamed: 2 Unnamed: 3  \
# 0              Company  Facebook     Google  Microsoft
# 1  2017-06-05 00:00:00       155        955         66
# 2  2017-06-06 00:00:00       150        987         69
# 3  2017-06-07 00:00:00       153        963         62
# 4  2017-06-08 00:00:00       155       1000         61
# 5  2017-06-09 00:00:00       156       1012         66
#
#   Price to earnings ratio (P/E) Unnamed: 5 Unnamed: 6
# 0                      Facebook     Google  Microsoft
# 1                          37.1         32      30.31
# 2                         36.98       31.3      30.56
# 3                         36.78       31.7      30.46
# 4                         36.11       31.2      30.11
# 5                         37.07         30         31

# %%
df=pd.read_excel("stocks.xlsx",index_col=[0])
df
# Out:
#                         Price Unnamed: 2 Unnamed: 3  \
# Company              Facebook     Google  Microsoft
# 2017-06-05 00:00:00       155        955         66
# 2017-06-06 00:00:00       150        987         69
# 2017-06-07 00:00:00       153        963         62
# 2017-06-08 00:00:00       155       1000         61
# 2017-06-09 00:00:00       156       1012         66
#
#                     Price to earnings ratio (P/E) Unnamed: 5 Unnamed: 6
# Company                                  Facebook     Google  Microsoft
# 2017-06-05 00:00:00                          37.1         32      30.31
# 2017-06-06 00:00:00                         36.98       31.3      30.56
# 2017-06-07 00:00:00                         36.78       31.7      30.46
# 2017-06-08 00:00:00                         36.11       31.2      30.11
# 2017-06-09 00:00:00                         37.07         30         31

# %%
df=pd.read_excel("stocks.xlsx",header=[0,1],index_col=[0])
df
# Out:
#               Price                  Price to earnings ratio (P/E)         \
# Company    Facebook Google Microsoft                      Facebook Google
# 2017-06-05      155    955        66                         37.10   32.0
# 2017-06-06      150    987        69                         36.98   31.3
# 2017-06-07      153    963        62                         36.78   31.7
# 2017-06-08      155   1000        61                         36.11   31.2
# 2017-06-09      156   1012        66                         37.07   30.0
#
#
# Company    Microsoft
# 2017-06-05     30.31
# 2017-06-06     30.56
# 2017-06-07     30.46
# 2017-06-08     30.11
# 2017-06-09     31.00

# %%
df_stacked=df.stack()
df_stacked
# Out:
#                       Price  Price to earnings ratio (P/E)
#            Company
# 2017-06-05 Facebook     155                          37.10
#            Google       955                          32.00
#            Microsoft     66                          30.31
# 2017-06-06 Facebook     150                          36.98
#            Google       987                          31.30
#            Microsoft     69                          30.56
# 2017-06-07 Facebook     153                          36.78
#            Google       963                          31.70
#            Microsoft     62                          30.46
# 2017-06-08 Facebook     155                          36.11
#            Google      1000                          31.20
#            Microsoft     61                          30.11
# 2017-06-09 Facebook     156                          37.07
#            Google      1012                          30.00
#            Microsoft     66                          31.00

# %%
df_stacked.unstack()
# Out:
#               Price                  Price to earnings ratio (P/E)         \
# Company    Facebook Google Microsoft                      Facebook Google
# 2017-06-05      155    955        66                         37.10   32.0
# 2017-06-06      150    987        69                         36.98   31.3
# 2017-06-07      153    963        62                         36.78   31.7
# 2017-06-08      155   1000        61                         36.11   31.2
# 2017-06-09      156   1012        66                         37.07   30.0
#
#
# Company    Microsoft
# 2017-06-05     30.31
# 2017-06-06     30.56
# 2017-06-07     30.46
# 2017-06-08     30.11
# 2017-06-09     31.00

# %%
df=pd.read_excel("stocks_3_levels.xlsx",header=[0,1,2],index_col=[0])
df
# Out:
#         Price Ratios                                                        \
#                Price                  Price to earnings ratio (P/E)
# Company     Facebook Google Microsoft                      Facebook Google
# Q1 2016          155    955        66                         37.10   32.0
# Q2 2016          150    987        69                         36.98   31.3
# Q3 2016          153    963        62                         36.78   31.7
# Q4 2016          155   1000        61                         36.11   31.2
# Q1 2017          156   1012        66                         37.07   30.0
#
#                   Income Statement                                     \
#                          Net Sales                  Net Profit
# Company Microsoft         Facebook Google Microsoft   Facebook Google
# Q1 2016     30.31              2.6     20     18.70       0.80   5.43
# Q2 2016     30.56              3.1     22     21.30       0.97   5.89
# ...

# %%
df.style.set_table_styles([{'selector' : '',
                            'props' : [('border',
                                        '10px solid yellow')]}])
# Out:
# <style type="text/css">
# #T_c1c23_  {
#   border: 10px solid yellow;
# }
# </style>
# <table id="T_c1c23_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" colspan="6">Price Ratios</th>
#       <th class="col_heading level0 col6" colspan="6">Income Statement</th>
#     </tr>
#     <tr>
#       <th class="blank level1" >&nbsp;</th>
#       <th class="col_heading level1 col0" colspan="3">Price</th>
#       <th class="col_heading level1 col3" colspan="3">Price to earnings ratio (P/E)</th>
#       <th class="col_heading level1 col6" colspan="3">Net Sales</th>
#       <th class="col_heading level1 col9" colspan="3">Net Profit</th>
#     </tr>
#     <tr>
#       <th class="index_name level2" >Company</th>
#       <th class="col_heading level2 col0" >Facebook</th>
#       <th class="col_heading level2 col1" >Google</th>
#       <th class="col_heading level2 col2" >Microsoft</th>
# ...

# %%
df.style.set_table_styles([{'selector':'','props':[('border','4px solid #7a7')]}])
# Out:
# <style type="text/css">
# #T_a1bc4_  {
#   border: 4px solid #7a7;
# }
# </style>
# <table id="T_a1bc4_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" colspan="6">Price Ratios</th>
#       <th class="col_heading level0 col6" colspan="6">Income Statement</th>
#     </tr>
#     <tr>
#       <th class="blank level1" >&nbsp;</th>
#       <th class="col_heading level1 col0" colspan="3">Price</th>
#       <th class="col_heading level1 col3" colspan="3">Price to earnings ratio (P/E)</th>
#       <th class="col_heading level1 col6" colspan="3">Net Sales</th>
#       <th class="col_heading level1 col9" colspan="3">Net Profit</th>
#     </tr>
#     <tr>
#       <th class="index_name level2" >Company</th>
#       <th class="col_heading level2 col0" >Facebook</th>
#       <th class="col_heading level2 col1" >Google</th>
#       <th class="col_heading level2 col2" >Microsoft</th>
# ...
